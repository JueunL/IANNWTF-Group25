# %%
import numpy as np
# %tensorflow_version 2.x
import tensorflow as tf
import matplotlib.pyplot as plt

# %% [markdown]
# ### Load the dataset.

# %%
from tensorflow.keras.layers import Input, Conv2D, MaxPooling2D, ZeroPadding2D,\
     Flatten, BatchNormalization, AveragePooling2D, Dense, Activation, Add, Dense, AveragePooling2D, Input, Flatten 
from tensorflow.keras.models import Model
from tensorflow.keras import activations
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2
from __future__ import print_function
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.datasets import cifar10
import numpy as np
import os
import tensorflow.keras

# %%
# Load the CIFAR10 data.
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 11s 0us/step

# %%
# Input normalization
train_images = (x_train/255)
test_images = (x_test/255)

# %%
train_labels, test_labels = y_train.reshape(-1), y_test.reshape(-1)

# %%
train_dataset_images = tf.data.Dataset.from_tensor_slices(train_images) 
print(train_dataset_images)
train_dataset_targets = tf.data.Dataset.from_tensor_slices(train_labels)
train_dataset_targets = train_dataset_targets.map(lambda t : tf.one_hot(t, 10)) 
print(train_dataset_targets)

train_dataset = tf.data.Dataset.zip((train_dataset_images, train_dataset_targets))
print(train_dataset)
train_dataset = train_dataset.batch(100)
train_dataset = train_dataset.shuffle(buffer_size=1000)

# repeat for the test dataset
test_dataset_images = tf.data.Dataset.from_tensor_slices(test_images)
test_dataset_targets = tf.data.Dataset.from_tensor_slices(test_labels)
test_dataset_targets = test_dataset_targets.map(lambda t : tf.one_hot(t, 10))

test_dataset = tf.data.Dataset.zip((test_dataset_images, test_dataset_targets))
test_dataset = test_dataset.batch(100)
test_dataset = test_dataset.shuffle(buffer_size=1000)
# Out:
# <TensorSliceDataset shapes: (32, 32, 3), types: tf.float64>
# <MapDataset shapes: (10,), types: tf.float32>
# <ZipDataset shapes: ((32, 32, 3), (10,)), types: (tf.float64, tf.float32)>

# %% [markdown]
# ResNet

# %%
def res_identity(x, filters): 
  #renet block where dimension doesnot change.
  #The skip connection is just simple identity conncection
  #we will have 3 blocks and then input will be added

  x_skip = x # this will be used for addition with the residual block 
  f1, f2 = filters

  #first block 
  x = Conv2D(f1, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)

  #second block # bottleneck (but size kept same with padding)
  x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)

  # third block activation used after adding the input
  x = Conv2D(f2, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)
  # x = Activation(activations.relu)(x)

  # add the input 
  x = Add()([x, x_skip])
  x = Activation(activations.relu)(x)

  return x

def res_conv(x, s, filters):
  '''
  here the input size changes''' 
  x_skip = x
  f1, f2 = filters

  # first block
  x = Conv2D(f1, kernel_size=(1, 1), strides=(s, s), padding='valid', kernel_regularizer=l2(0.001))(x)
  # when s = 2 then it is like downsizing the feature map
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)

  # second block
  x = Conv2D(f1, kernel_size=(3, 3), strides=(1, 1), padding='same', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)

  #third block
  x = Conv2D(f2, kernel_size=(1, 1), strides=(1, 1), padding='valid', kernel_regularizer=l2(0.001))(x)
  x = BatchNormalization()(x)

  # shortcut 
  x_skip = Conv2D(f2, kernel_size=(1, 1), strides=(s, s), padding='valid', kernel_regularizer=l2(0.001))(x_skip)
  x_skip = BatchNormalization()(x_skip)

  # add 
  x = Add()([x, x_skip])
  x = Activation(activations.relu)(x)

  return x

def resnet50():

  input_im = Input(shape=(train_images.shape[1], train_images.shape[2], train_images.shape[3])) # cifar 10 images size
  x = tf.keras.layers.ZeroPadding2D(padding=(3, 3))(input_im)

  # 1st stage
  # here we perform maxpooling, see the figure above

  x = Conv2D(64, kernel_size=(7, 7), strides=(2, 2))(x)
  x = BatchNormalization()(x)
  x = Activation(activations.relu)(x)
  x = MaxPooling2D((3, 3), strides=(2, 2))(x)

  #2nd stage 
  # frm here on only conv block and identity block, no pooling

  x = res_conv(x, s=1, filters=(64, 256))
  x = res_identity(x, filters=(64, 256))
  x = res_identity(x, filters=(64, 256))

  # 3rd stage

  x = res_conv(x, s=2, filters=(128, 512))
  x = res_identity(x, filters=(128, 512))
  x = res_identity(x, filters=(128, 512))
  x = res_identity(x, filters=(128, 512))

  # 4th stage

  x = res_conv(x, s=2, filters=(256, 1024))
  x = res_identity(x, filters=(256, 1024))
  x = res_identity(x, filters=(256, 1024))
  x = res_identity(x, filters=(256, 1024))
  x = res_identity(x, filters=(256, 1024))
  x = res_identity(x, filters=(256, 1024))

  # 5th stage

  x = res_conv(x, s=2, filters=(512, 2048))
  x = res_identity(x, filters=(512, 2048))
  x = res_identity(x, filters=(512, 2048))

  # ends with average pooling and dense connection

  x = AveragePooling2D((2, 2), padding='same')(x)

  x = Flatten()(x)
  x = Dense(num_classes, activation='softmax', kernel_initializer='he_normal')(x) #multi-class

  # define the model 

  model = Model(inputs=input_im, outputs=x, name='Resnet50')

  return model

# %%
def train_step(model, input, target, loss_function, optimizer):
  # loss_object and optimizer_object are instances of respective tensorflow classes
  with tf.GradientTape() as tape:
    prediction = model(input, training = True)
    loss = loss_function(target, prediction)
    gradients = tape.gradient(loss, model.trainable_variables)
  optimizer.apply_gradients(zip(gradients, model.trainable_variables))
  return loss 

def test(model, test_data, loss_function, training = False):
  # test over complete test data

  test_accuracy_aggregator = []
  test_loss_aggregator = []

  for (input, target) in test_data:
    prediction = model(input, training = False)
    sample_test_loss = loss_function(target, prediction)
    sample_test_accuracy =  np.argmax(target, axis=1) == np.argmax(prediction, axis=1)
    sample_test_accuracy = np.mean(sample_test_accuracy)
    test_loss_aggregator.append(sample_test_loss.numpy())
    test_accuracy_aggregator.append(np.mean(sample_test_accuracy))

  test_loss = np.mean(test_loss_aggregator)
  test_accuracy = np.mean(test_accuracy_aggregator)

  return test_loss, test_accuracy
  


tf.keras.backend.clear_session()

### Hyperparameters
num_epochs = 30
learning_rate = 0.001
running_average_factor = 0.95
seed = 1
cross_entropy_loss = tf.keras.losses.BinaryCrossentropy()
# Initialize the optimizer: Adam with default parameters. Check out 'tf.keras.optimizers'
optimizer = tf.keras.optimizers.Adam(learning_rate)

num_classes = 10
model = resnet50()
# Initialize lists for later visualization.
train_losses = []

test_losses = []
test_accuracies = []

#testing once before we begin
test_loss, test_accuracy = test(model, test_dataset, cross_entropy_loss)
test_losses.append(test_loss)
test_accuracies.append(test_accuracy)

#check how model performs on train data once before we begin
train_loss, _ = test(model, train_dataset, cross_entropy_loss)
train_losses.append(train_loss)

# We train for num_epochs epochs.
for epoch in range(num_epochs):
    print('Epoch: __ ' + str(epoch))

    train_dataset = train_dataset.shuffle(buffer_size=100)
    test_dataset = test_dataset.shuffle(buffer_size=100)

    #training (and checking in with training)
    running_average = 0
    for (input,target) in train_dataset:
        train_loss = train_step(model, input, target, cross_entropy_loss, optimizer)
        running_average = running_average_factor * running_average  + (1 - running_average_factor) * train_loss
    train_losses.append(running_average)

    #testing
    test_loss, test_accuracy = test(model, test_dataset, cross_entropy_loss)
    test_losses.append(test_loss)
    test_accuracies.append(test_accuracy)

plt.figure()
line1, = plt.plot(train_losses)
line2, = plt.plot(test_losses)
plt.xlabel("Training steps")
plt.ylabel("Loss")
plt.legend((line1,line2),("training","test"))
plt.show()

plt.figure()
line1, = plt.plot(test_accuracies)
plt.title('accuracy: '+ str(np.max(test_accuracies)))
plt.xlabel("Training steps")
plt.ylabel("Accuracy")
plt.show()
# Out:
# Epoch: __ 0
# Epoch: __ 1
# Epoch: __ 2
# Epoch: __ 3
# Epoch: __ 4
# Epoch: __ 5
# Epoch: __ 6
# Epoch: __ 7
# Epoch: __ 8
# Epoch: __ 9
# Epoch: __ 10
# Epoch: __ 11
# Epoch: __ 12
# Epoch: __ 13
# Epoch: __ 14
# Epoch: __ 15
# Epoch: __ 16
# Epoch: __ 17
# Epoch: __ 18
# Epoch: __ 19
# Epoch: __ 20
# Epoch: __ 21
# Epoch: __ 22
# Epoch: __ 23
# Epoch: __ 24
# Epoch: __ 25
# Epoch: __ 26
# Epoch: __ 27
# Epoch: __ 28
# Epoch: __ 29

# %% [markdown]
# ## DenseNet

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

from tensorflow.keras.layers import Dense, Conv2D, BatchNormalization
from tensorflow.keras.layers import MaxPooling2D, AveragePooling2D
from tensorflow.keras.layers import Input, Flatten, Dropout
from tensorflow.keras.layers import concatenate, Activation
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.callbacks import LearningRateScheduler
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model
from tensorflow.keras.datasets import cifar10
from tensorflow.keras.utils import plot_model
from tensorflow.keras.utils import to_categorical
import os
import numpy as np
import math

# training parameters
batch_size = 32
epochs = 100
data_augmentation = True

# network parameters
num_classes = 10
num_dense_blocks = 3
use_max_pool = False


growth_rate = 12
depth = 100
num_bottleneck_layers = (depth - 4) // (2 * num_dense_blocks)

num_filters_bef_dense_block = 2 * growth_rate
compression_factor = 0.5

# load the CIFAR10 data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()

# input image dimensions
input_shape = x_train.shape[1:]

# mormalize data
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255
print('x_train shape:', x_train.shape)
print(x_train.shape[0], 'train samples')
print(x_test.shape[0], 'test samples')
print('y_train shape:', y_train.shape)

# convert class vectors to binary class matrices.
y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)

def lr_schedule(epoch):
    """Learning Rate Schedule
    Learning rate is scheduled to be reduced after 80, 120, 160, 180 epochs.
    Called automatically every epoch as part of callbacks during training.
    # Arguments
        epoch (int): The number of epochs
    # Returns
        lr (float32): learning rate
    """
    lr = 1e-3
    if epoch > 180:
        lr *= 0.5e-3
    elif epoch > 160:
        lr *= 1e-3
    elif epoch > 120:
        lr *= 1e-2
    elif epoch > 80:
        lr *= 1e-1
    print('Learning rate: ', lr)
    return lr


# start model definition
# densenet CNNs (composite function) are made of BN-ReLU-Conv2D
inputs = Input(shape=input_shape)
x = BatchNormalization()(inputs)
x = Activation('relu')(x)
x = Conv2D(num_filters_bef_dense_block,
           kernel_size=3,
           padding='same',
           kernel_initializer='he_normal')(x)
x = concatenate([inputs, x])

# stack of dense blocks bridged by transition layers
for i in range(num_dense_blocks):
    # a dense block is a stack of bottleneck layers
    for j in range(num_bottleneck_layers):
        y = BatchNormalization()(x)
        y = Activation('relu')(y)
        y = Conv2D(4 * growth_rate,
                   kernel_size=1,
                   padding='same',
                   kernel_initializer='he_normal')(y)
        if not data_augmentation:
            y = Dropout(0.2)(y)
        y = BatchNormalization()(y)
        y = Activation('relu')(y)
        y = Conv2D(growth_rate,
                   kernel_size=3,
                   padding='same',
                   kernel_initializer='he_normal')(y)
        if not data_augmentation:
            y = Dropout(0.2)(y)
        x = concatenate([x, y])

    # no transition layer after the last dense block
    if i == num_dense_blocks - 1:
        continue

    # transition layer compresses num of feature maps and reduces the size by 2
    num_filters_bef_dense_block += num_bottleneck_layers * growth_rate
    num_filters_bef_dense_block = int(num_filters_bef_dense_block * compression_factor)
    y = BatchNormalization()(x)
    y = Conv2D(num_filters_bef_dense_block,
               kernel_size=1,
               padding='same',
               kernel_initializer='he_normal')(y)
    if not data_augmentation:
        y = Dropout(0.2)(y)
    x = AveragePooling2D()(y)


# add classifier on top
# after average pooling, size of feature map is 1 x 1
x = AveragePooling2D(pool_size=8)(x)
y = Flatten()(x)
outputs = Dense(num_classes,
                kernel_initializer='he_normal',
                activation='softmax')(y)

# instantiate and compile model
# orig paper uses SGD but RMSprop works better for DenseNet
model = Model(inputs=inputs, outputs=outputs)
model.compile(loss='categorical_crossentropy',
              optimizer=RMSprop(1e-3),
              metrics=['acc'])
model.summary()
# enable this if pydot can be installed
# pip install pydot
#plot_model(model, to_file="cifar10-densenet.png", show_shapes=True)

# prepare model model saving directory
save_dir = os.path.join(os.getcwd(), 'saved_models')
model_name = 'cifar10_densenet_model.{epoch:02d}.h5'
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
filepath = os.path.join(save_dir, model_name)

# prepare callbacks for model saving and for learning rate reducer
checkpoint = ModelCheckpoint(filepath=filepath,
                             monitor='val_acc',
                             verbose=1,
                             save_best_only=True)

lr_scheduler = LearningRateScheduler(lr_schedule)

lr_reducer = ReduceLROnPlateau(factor=np.sqrt(0.1),
                               cooldown=0,
                               patience=5,
                               min_lr=0.5e-6)

callbacks = [checkpoint, lr_reducer, lr_scheduler]

# run training, with or without data augmentation
if not data_augmentation:
    print('Not using data augmentation.')
    model.fit(x_train, y_train,
              batch_size=batch_size,
              epochs=epochs,
              validation_data=(x_test, y_test),
              shuffle=True,
              callbacks=callbacks)
else:
    print('Using real-time data augmentation.')
    # preprocessing  and realtime data augmentation
    datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=0,  # randomly rotate images in the range (deg 0 to 180)
        width_shift_range=0.1,  # randomly shift images horizontally
        height_shift_range=0.1,  # randomly shift images vertically
        horizontal_flip=True,  # randomly flip images
        vertical_flip=False)  # randomly flip images

    # compute quantities required for featurewise normalization
    # (std, mean, and principal components if ZCA whitening is applied)
    datagen.fit(x_train)

    steps_per_epoch = math.ceil(len(x_train) / batch_size)
    # fit the model on the batches generated by datagen.flow().
    model.fit(x=datagen.flow(x_train, y_train, batch_size=batch_size),
              verbose=1,
              epochs=epochs,
              validation_data=(x_test, y_test),
              steps_per_epoch=steps_per_epoch,
              callbacks=callbacks)


    # fit the model on the batches generated by datagen.flow()
    #model.fit_generator(datagen.flow(x_train, y_train, batch_size=batch_size),
    ##                    steps_per_epoch=x_train.shape[0] // batch_size,
    #                    validation_data=(x_test, y_test),
    #                    epochs=epochs, verbose=1,
    #                    callbacks=callbacks)

# score trained model
scores = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', scores[0])
print('Test accuracy:', scores[1])
# Out:
# x_train shape: (50000, 32, 32, 3)
# 50000 train samples
# 10000 test samples
# y_train shape: (50000, 1)
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 32, 32, 3)]  0
# __________________________________________________________________________________________________
# batch_normalization_53 (BatchNo (None, 32, 32, 3)    12          input_2[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 32, 32, 3)    0           batch_normalization_53[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 32, 32, 24)   672         activation_49[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 27)   0           input_2[0][0]
#                                                                  conv2d_53[0][0]
# __________________________________________________________________________________________________
# batch_normalization_54 (BatchNo (None, 32, 32, 27)   108         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 32, 32, 27)   0           batch_normalization_54[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 32, 32, 48)   1344        activation_50[0][0]
# __________________________________________________________________________________________________
# batch_normalization_55 (BatchNo (None, 32, 32, 48)   192         conv2d_54[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 32, 32, 48)   0           batch_normalization_55[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 32, 32, 12)   5196        activation_51[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 32, 32, 39)   0           concatenate[0][0]
#                                                                  conv2d_55[0][0]
# __________________________________________________________________________________________________
# batch_normalization_56 (BatchNo (None, 32, 32, 39)   156         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 32, 32, 39)   0           batch_normalization_56[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 32, 32, 48)   1920        activation_52[0][0]
# __________________________________________________________________________________________________
# batch_normalization_57 (BatchNo (None, 32, 32, 48)   192         conv2d_56[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 32, 32, 48)   0           batch_normalization_57[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 32, 32, 12)   5196        activation_53[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 51)   0           concatenate_1[0][0]
#                                                                  conv2d_57[0][0]
# __________________________________________________________________________________________________
# batch_normalization_58 (BatchNo (None, 32, 32, 51)   204         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 32, 32, 51)   0           batch_normalization_58[0][0]
# __________________________________________________________________________________________________
# conv2d_58 (Conv2D)              (None, 32, 32, 48)   2496        activation_54[0][0]
# __________________________________________________________________________________________________
# batch_normalization_59 (BatchNo (None, 32, 32, 48)   192         conv2d_58[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 32, 32, 48)   0           batch_normalization_59[0][0]
# __________________________________________________________________________________________________
# conv2d_59 (Conv2D)              (None, 32, 32, 12)   5196        activation_55[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 32, 32, 63)   0           concatenate_2[0][0]
#                                                                  conv2d_59[0][0]
# __________________________________________________________________________________________________
# batch_normalization_60 (BatchNo (None, 32, 32, 63)   252         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 32, 32, 63)   0           batch_normalization_60[0][0]
# __________________________________________________________________________________________________
# conv2d_60 (Conv2D)              (None, 32, 32, 48)   3072        activation_56[0][0]
# __________________________________________________________________________________________________
# batch_normalization_61 (BatchNo (None, 32, 32, 48)   192         conv2d_60[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 32, 32, 48)   0           batch_normalization_61[0][0]
# __________________________________________________________________________________________________
# conv2d_61 (Conv2D)              (None, 32, 32, 12)   5196        activation_57[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 32, 32, 75)   0           concatenate_3[0][0]
#                                                                  conv2d_61[0][0]
# __________________________________________________________________________________________________
# batch_normalization_62 (BatchNo (None, 32, 32, 75)   300         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 32, 32, 75)   0           batch_normalization_62[0][0]
# __________________________________________________________________________________________________
# conv2d_62 (Conv2D)              (None, 32, 32, 48)   3648        activation_58[0][0]
# __________________________________________________________________________________________________
# batch_normalization_63 (BatchNo (None, 32, 32, 48)   192         conv2d_62[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 32, 32, 48)   0           batch_normalization_63[0][0]
# __________________________________________________________________________________________________
# conv2d_63 (Conv2D)              (None, 32, 32, 12)   5196        activation_59[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 32, 32, 87)   0           concatenate_4[0][0]
#                                                                  conv2d_63[0][0]
# __________________________________________________________________________________________________
# batch_normalization_64 (BatchNo (None, 32, 32, 87)   348         concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 32, 32, 87)   0           batch_normalization_64[0][0]
# __________________________________________________________________________________________________
# conv2d_64 (Conv2D)              (None, 32, 32, 48)   4224        activation_60[0][0]
# __________________________________________________________________________________________________
# batch_normalization_65 (BatchNo (None, 32, 32, 48)   192         conv2d_64[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 32, 32, 48)   0           batch_normalization_65[0][0]
# __________________________________________________________________________________________________
# conv2d_65 (Conv2D)              (None, 32, 32, 12)   5196        activation_61[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 99)   0           concatenate_5[0][0]
#                                                                  conv2d_65[0][0]
# __________________________________________________________________________________________________
# batch_normalization_66 (BatchNo (None, 32, 32, 99)   396         concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 32, 32, 99)   0           batch_normalization_66[0][0]
# __________________________________________________________________________________________________
# conv2d_66 (Conv2D)              (None, 32, 32, 48)   4800        activation_62[0][0]
# __________________________________________________________________________________________________
# batch_normalization_67 (BatchNo (None, 32, 32, 48)   192         conv2d_66[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 32, 32, 48)   0           batch_normalization_67[0][0]
# __________________________________________________________________________________________________
# conv2d_67 (Conv2D)              (None, 32, 32, 12)   5196        activation_63[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 32, 32, 111)  0           concatenate_6[0][0]
#                                                                  conv2d_67[0][0]
# __________________________________________________________________________________________________
# batch_normalization_68 (BatchNo (None, 32, 32, 111)  444         concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 32, 32, 111)  0           batch_normalization_68[0][0]
# __________________________________________________________________________________________________
# conv2d_68 (Conv2D)              (None, 32, 32, 48)   5376        activation_64[0][0]
# __________________________________________________________________________________________________
# batch_normalization_69 (BatchNo (None, 32, 32, 48)   192         conv2d_68[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 32, 32, 48)   0           batch_normalization_69[0][0]
# __________________________________________________________________________________________________
# conv2d_69 (Conv2D)              (None, 32, 32, 12)   5196        activation_65[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 32, 32, 123)  0           concatenate_7[0][0]
#                                                                  conv2d_69[0][0]
# __________________________________________________________________________________________________
# batch_normalization_70 (BatchNo (None, 32, 32, 123)  492         concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 32, 32, 123)  0           batch_normalization_70[0][0]
# __________________________________________________________________________________________________
# conv2d_70 (Conv2D)              (None, 32, 32, 48)   5952        activation_66[0][0]
# __________________________________________________________________________________________________
# batch_normalization_71 (BatchNo (None, 32, 32, 48)   192         conv2d_70[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 32, 32, 48)   0           batch_normalization_71[0][0]
# __________________________________________________________________________________________________
# conv2d_71 (Conv2D)              (None, 32, 32, 12)   5196        activation_67[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 32, 32, 135)  0           concatenate_8[0][0]
#                                                                  conv2d_71[0][0]
# __________________________________________________________________________________________________
# batch_normalization_72 (BatchNo (None, 32, 32, 135)  540         concatenate_9[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 32, 32, 135)  0           batch_normalization_72[0][0]
# __________________________________________________________________________________________________
# conv2d_72 (Conv2D)              (None, 32, 32, 48)   6528        activation_68[0][0]
# __________________________________________________________________________________________________
# batch_normalization_73 (BatchNo (None, 32, 32, 48)   192         conv2d_72[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 32, 32, 48)   0           batch_normalization_73[0][0]
# __________________________________________________________________________________________________
# conv2d_73 (Conv2D)              (None, 32, 32, 12)   5196        activation_69[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 32, 32, 147)  0           concatenate_9[0][0]
#                                                                  conv2d_73[0][0]
# __________________________________________________________________________________________________
# batch_normalization_74 (BatchNo (None, 32, 32, 147)  588         concatenate_10[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 32, 32, 147)  0           batch_normalization_74[0][0]
# __________________________________________________________________________________________________
# conv2d_74 (Conv2D)              (None, 32, 32, 48)   7104        activation_70[0][0]
# __________________________________________________________________________________________________
# batch_normalization_75 (BatchNo (None, 32, 32, 48)   192         conv2d_74[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 32, 32, 48)   0           batch_normalization_75[0][0]
# __________________________________________________________________________________________________
# conv2d_75 (Conv2D)              (None, 32, 32, 12)   5196        activation_71[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 32, 32, 159)  0           concatenate_10[0][0]
#                                                                  conv2d_75[0][0]
# __________________________________________________________________________________________________
# batch_normalization_76 (BatchNo (None, 32, 32, 159)  636         concatenate_11[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 32, 32, 159)  0           batch_normalization_76[0][0]
# __________________________________________________________________________________________________
# conv2d_76 (Conv2D)              (None, 32, 32, 48)   7680        activation_72[0][0]
# __________________________________________________________________________________________________
# batch_normalization_77 (BatchNo (None, 32, 32, 48)   192         conv2d_76[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 32, 32, 48)   0           batch_normalization_77[0][0]
# __________________________________________________________________________________________________
# conv2d_77 (Conv2D)              (None, 32, 32, 12)   5196        activation_73[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 32, 32, 171)  0           concatenate_11[0][0]
#                                                                  conv2d_77[0][0]
# __________________________________________________________________________________________________
# batch_normalization_78 (BatchNo (None, 32, 32, 171)  684         concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 32, 32, 171)  0           batch_normalization_78[0][0]
# __________________________________________________________________________________________________
# conv2d_78 (Conv2D)              (None, 32, 32, 48)   8256        activation_74[0][0]
# __________________________________________________________________________________________________
# batch_normalization_79 (BatchNo (None, 32, 32, 48)   192         conv2d_78[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 32, 32, 48)   0           batch_normalization_79[0][0]
# __________________________________________________________________________________________________
# conv2d_79 (Conv2D)              (None, 32, 32, 12)   5196        activation_75[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 32, 32, 183)  0           concatenate_12[0][0]
#                                                                  conv2d_79[0][0]
# __________________________________________________________________________________________________
# batch_normalization_80 (BatchNo (None, 32, 32, 183)  732         concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 32, 32, 183)  0           batch_normalization_80[0][0]
# __________________________________________________________________________________________________
# conv2d_80 (Conv2D)              (None, 32, 32, 48)   8832        activation_76[0][0]
# __________________________________________________________________________________________________
# batch_normalization_81 (BatchNo (None, 32, 32, 48)   192         conv2d_80[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 32, 32, 48)   0           batch_normalization_81[0][0]
# __________________________________________________________________________________________________
# conv2d_81 (Conv2D)              (None, 32, 32, 12)   5196        activation_77[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 32, 32, 195)  0           concatenate_13[0][0]
#                                                                  conv2d_81[0][0]
# __________________________________________________________________________________________________
# batch_normalization_82 (BatchNo (None, 32, 32, 195)  780         concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 32, 32, 195)  0           batch_normalization_82[0][0]
# __________________________________________________________________________________________________
# conv2d_82 (Conv2D)              (None, 32, 32, 48)   9408        activation_78[0][0]
# __________________________________________________________________________________________________
# batch_normalization_83 (BatchNo (None, 32, 32, 48)   192         conv2d_82[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 32, 32, 48)   0           batch_normalization_83[0][0]
# __________________________________________________________________________________________________
# conv2d_83 (Conv2D)              (None, 32, 32, 12)   5196        activation_79[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 32, 32, 207)  0           concatenate_14[0][0]
#                                                                  conv2d_83[0][0]
# __________________________________________________________________________________________________
# batch_normalization_84 (BatchNo (None, 32, 32, 207)  828         concatenate_15[0][0]
# __________________________________________________________________________________________________
# activation_80 (Activation)      (None, 32, 32, 207)  0           batch_normalization_84[0][0]
# __________________________________________________________________________________________________
# conv2d_84 (Conv2D)              (None, 32, 32, 48)   9984        activation_80[0][0]
# __________________________________________________________________________________________________
# batch_normalization_85 (BatchNo (None, 32, 32, 48)   192         conv2d_84[0][0]
# __________________________________________________________________________________________________
# activation_81 (Activation)      (None, 32, 32, 48)   0           batch_normalization_85[0][0]
# __________________________________________________________________________________________________
# conv2d_85 (Conv2D)              (None, 32, 32, 12)   5196        activation_81[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 32, 32, 219)  0           concatenate_15[0][0]
#                                                                  conv2d_85[0][0]
# __________________________________________________________________________________________________
# batch_normalization_86 (BatchNo (None, 32, 32, 219)  876         concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_86 (Conv2D)              (None, 32, 32, 108)  23760       batch_normalization_86[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 16, 16, 108)  0           conv2d_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_87 (BatchNo (None, 16, 16, 108)  432         average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_82 (Activation)      (None, 16, 16, 108)  0           batch_normalization_87[0][0]
# __________________________________________________________________________________________________
# conv2d_87 (Conv2D)              (None, 16, 16, 48)   5232        activation_82[0][0]
# __________________________________________________________________________________________________
# batch_normalization_88 (BatchNo (None, 16, 16, 48)   192         conv2d_87[0][0]
# __________________________________________________________________________________________________
# activation_83 (Activation)      (None, 16, 16, 48)   0           batch_normalization_88[0][0]
# __________________________________________________________________________________________________
# conv2d_88 (Conv2D)              (None, 16, 16, 12)   5196        activation_83[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 16, 16, 120)  0           average_pooling2d_1[0][0]
#                                                                  conv2d_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_89 (BatchNo (None, 16, 16, 120)  480         concatenate_17[0][0]
# __________________________________________________________________________________________________
# activation_84 (Activation)      (None, 16, 16, 120)  0           batch_normalization_89[0][0]
# __________________________________________________________________________________________________
# conv2d_89 (Conv2D)              (None, 16, 16, 48)   5808        activation_84[0][0]
# __________________________________________________________________________________________________
# batch_normalization_90 (BatchNo (None, 16, 16, 48)   192         conv2d_89[0][0]
# __________________________________________________________________________________________________
# activation_85 (Activation)      (None, 16, 16, 48)   0           batch_normalization_90[0][0]
# __________________________________________________________________________________________________
# conv2d_90 (Conv2D)              (None, 16, 16, 12)   5196        activation_85[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 16, 16, 132)  0           concatenate_17[0][0]
#                                                                  conv2d_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_91 (BatchNo (None, 16, 16, 132)  528         concatenate_18[0][0]
# __________________________________________________________________________________________________
# activation_86 (Activation)      (None, 16, 16, 132)  0           batch_normalization_91[0][0]
# __________________________________________________________________________________________________
# conv2d_91 (Conv2D)              (None, 16, 16, 48)   6384        activation_86[0][0]
# __________________________________________________________________________________________________
# batch_normalization_92 (BatchNo (None, 16, 16, 48)   192         conv2d_91[0][0]
# __________________________________________________________________________________________________
# activation_87 (Activation)      (None, 16, 16, 48)   0           batch_normalization_92[0][0]
# __________________________________________________________________________________________________
# conv2d_92 (Conv2D)              (None, 16, 16, 12)   5196        activation_87[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 16, 16, 144)  0           concatenate_18[0][0]
#                                                                  conv2d_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_93 (BatchNo (None, 16, 16, 144)  576         concatenate_19[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 16, 16, 144)  0           batch_normalization_93[0][0]
# __________________________________________________________________________________________________
# conv2d_93 (Conv2D)              (None, 16, 16, 48)   6960        activation_88[0][0]
# __________________________________________________________________________________________________
# batch_normalization_94 (BatchNo (None, 16, 16, 48)   192         conv2d_93[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 16, 16, 48)   0           batch_normalization_94[0][0]
# __________________________________________________________________________________________________
# conv2d_94 (Conv2D)              (None, 16, 16, 12)   5196        activation_89[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 16, 16, 156)  0           concatenate_19[0][0]
#                                                                  conv2d_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_95 (BatchNo (None, 16, 16, 156)  624         concatenate_20[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 16, 16, 156)  0           batch_normalization_95[0][0]
# __________________________________________________________________________________________________
# conv2d_95 (Conv2D)              (None, 16, 16, 48)   7536        activation_90[0][0]
# __________________________________________________________________________________________________
# batch_normalization_96 (BatchNo (None, 16, 16, 48)   192         conv2d_95[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 16, 16, 48)   0           batch_normalization_96[0][0]
# __________________________________________________________________________________________________
# conv2d_96 (Conv2D)              (None, 16, 16, 12)   5196        activation_91[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 16, 16, 168)  0           concatenate_20[0][0]
#                                                                  conv2d_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_97 (BatchNo (None, 16, 16, 168)  672         concatenate_21[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 16, 16, 168)  0           batch_normalization_97[0][0]
# __________________________________________________________________________________________________
# conv2d_97 (Conv2D)              (None, 16, 16, 48)   8112        activation_92[0][0]
# __________________________________________________________________________________________________
# batch_normalization_98 (BatchNo (None, 16, 16, 48)   192         conv2d_97[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 16, 16, 48)   0           batch_normalization_98[0][0]
# __________________________________________________________________________________________________
# conv2d_98 (Conv2D)              (None, 16, 16, 12)   5196        activation_93[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 16, 16, 180)  0           concatenate_21[0][0]
#                                                                  conv2d_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_99 (BatchNo (None, 16, 16, 180)  720         concatenate_22[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 16, 16, 180)  0           batch_normalization_99[0][0]
# __________________________________________________________________________________________________
# conv2d_99 (Conv2D)              (None, 16, 16, 48)   8688        activation_94[0][0]
# __________________________________________________________________________________________________
# batch_normalization_100 (BatchN (None, 16, 16, 48)   192         conv2d_99[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 16, 16, 48)   0           batch_normalization_100[0][0]
# __________________________________________________________________________________________________
# conv2d_100 (Conv2D)             (None, 16, 16, 12)   5196        activation_95[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 16, 16, 192)  0           concatenate_22[0][0]
#                                                                  conv2d_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_101 (BatchN (None, 16, 16, 192)  768         concatenate_23[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 16, 16, 192)  0           batch_normalization_101[0][0]
# __________________________________________________________________________________________________
# conv2d_101 (Conv2D)             (None, 16, 16, 48)   9264        activation_96[0][0]
# __________________________________________________________________________________________________
# batch_normalization_102 (BatchN (None, 16, 16, 48)   192         conv2d_101[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 16, 16, 48)   0           batch_normalization_102[0][0]
# __________________________________________________________________________________________________
# conv2d_102 (Conv2D)             (None, 16, 16, 12)   5196        activation_97[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 16, 16, 204)  0           concatenate_23[0][0]
#                                                                  conv2d_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_103 (BatchN (None, 16, 16, 204)  816         concatenate_24[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 16, 16, 204)  0           batch_normalization_103[0][0]
# __________________________________________________________________________________________________
# conv2d_103 (Conv2D)             (None, 16, 16, 48)   9840        activation_98[0][0]
# __________________________________________________________________________________________________
# batch_normalization_104 (BatchN (None, 16, 16, 48)   192         conv2d_103[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 16, 16, 48)   0           batch_normalization_104[0][0]
# __________________________________________________________________________________________________
# conv2d_104 (Conv2D)             (None, 16, 16, 12)   5196        activation_99[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 16, 16, 216)  0           concatenate_24[0][0]
#                                                                  conv2d_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_105 (BatchN (None, 16, 16, 216)  864         concatenate_25[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 16, 16, 216)  0           batch_normalization_105[0][0]
# __________________________________________________________________________________________________
# conv2d_105 (Conv2D)             (None, 16, 16, 48)   10416       activation_100[0][0]
# __________________________________________________________________________________________________
# batch_normalization_106 (BatchN (None, 16, 16, 48)   192         conv2d_105[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 16, 16, 48)   0           batch_normalization_106[0][0]
# __________________________________________________________________________________________________
# conv2d_106 (Conv2D)             (None, 16, 16, 12)   5196        activation_101[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 16, 16, 228)  0           concatenate_25[0][0]
#                                                                  conv2d_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_107 (BatchN (None, 16, 16, 228)  912         concatenate_26[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 16, 16, 228)  0           batch_normalization_107[0][0]
# __________________________________________________________________________________________________
# conv2d_107 (Conv2D)             (None, 16, 16, 48)   10992       activation_102[0][0]
# __________________________________________________________________________________________________
# batch_normalization_108 (BatchN (None, 16, 16, 48)   192         conv2d_107[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 16, 16, 48)   0           batch_normalization_108[0][0]
# __________________________________________________________________________________________________
# conv2d_108 (Conv2D)             (None, 16, 16, 12)   5196        activation_103[0][0]
# __________________________________________________________________________________________________
# concatenate_27 (Concatenate)    (None, 16, 16, 240)  0           concatenate_26[0][0]
#                                                                  conv2d_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_109 (BatchN (None, 16, 16, 240)  960         concatenate_27[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 16, 16, 240)  0           batch_normalization_109[0][0]
# __________________________________________________________________________________________________
# conv2d_109 (Conv2D)             (None, 16, 16, 48)   11568       activation_104[0][0]
# __________________________________________________________________________________________________
# batch_normalization_110 (BatchN (None, 16, 16, 48)   192         conv2d_109[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 16, 16, 48)   0           batch_normalization_110[0][0]
# __________________________________________________________________________________________________
# conv2d_110 (Conv2D)             (None, 16, 16, 12)   5196        activation_105[0][0]
# __________________________________________________________________________________________________
# concatenate_28 (Concatenate)    (None, 16, 16, 252)  0           concatenate_27[0][0]
#                                                                  conv2d_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_111 (BatchN (None, 16, 16, 252)  1008        concatenate_28[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 16, 16, 252)  0           batch_normalization_111[0][0]
# __________________________________________________________________________________________________
# conv2d_111 (Conv2D)             (None, 16, 16, 48)   12144       activation_106[0][0]
# __________________________________________________________________________________________________
# batch_normalization_112 (BatchN (None, 16, 16, 48)   192         conv2d_111[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 16, 16, 48)   0           batch_normalization_112[0][0]
# __________________________________________________________________________________________________
# conv2d_112 (Conv2D)             (None, 16, 16, 12)   5196        activation_107[0][0]
# __________________________________________________________________________________________________
# concatenate_29 (Concatenate)    (None, 16, 16, 264)  0           concatenate_28[0][0]
#                                                                  conv2d_112[0][0]
# __________________________________________________________________________________________________
# batch_normalization_113 (BatchN (None, 16, 16, 264)  1056        concatenate_29[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 16, 16, 264)  0           batch_normalization_113[0][0]
# __________________________________________________________________________________________________
# conv2d_113 (Conv2D)             (None, 16, 16, 48)   12720       activation_108[0][0]
# __________________________________________________________________________________________________
# batch_normalization_114 (BatchN (None, 16, 16, 48)   192         conv2d_113[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 16, 16, 48)   0           batch_normalization_114[0][0]
# __________________________________________________________________________________________________
# conv2d_114 (Conv2D)             (None, 16, 16, 12)   5196        activation_109[0][0]
# __________________________________________________________________________________________________
# concatenate_30 (Concatenate)    (None, 16, 16, 276)  0           concatenate_29[0][0]
#                                                                  conv2d_114[0][0]
# __________________________________________________________________________________________________
# batch_normalization_115 (BatchN (None, 16, 16, 276)  1104        concatenate_30[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 16, 16, 276)  0           batch_normalization_115[0][0]
# __________________________________________________________________________________________________
# conv2d_115 (Conv2D)             (None, 16, 16, 48)   13296       activation_110[0][0]
# __________________________________________________________________________________________________
# batch_normalization_116 (BatchN (None, 16, 16, 48)   192         conv2d_115[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 16, 16, 48)   0           batch_normalization_116[0][0]
# __________________________________________________________________________________________________
# conv2d_116 (Conv2D)             (None, 16, 16, 12)   5196        activation_111[0][0]
# __________________________________________________________________________________________________
# concatenate_31 (Concatenate)    (None, 16, 16, 288)  0           concatenate_30[0][0]
# ...
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 8, 8, 48)     15312       activation_142[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 8, 8, 48)     192         conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 8, 8, 48)     0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 8, 8, 12)     5196        activation_143[0][0]
# __________________________________________________________________________________________________
# concatenate_47 (Concatenate)    (None, 8, 8, 330)    0           concatenate_46[0][0]
#                                                                  conv2d_149[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 8, 8, 330)    1320        concatenate_47[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 8, 8, 330)    0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 8, 8, 48)     15888       activation_144[0][0]
# __________________________________________________________________________________________________
# batch_normalization_151 (BatchN (None, 8, 8, 48)     192         conv2d_150[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 8, 8, 48)     0           batch_normalization_151[0][0]
# __________________________________________________________________________________________________
# conv2d_151 (Conv2D)             (None, 8, 8, 12)     5196        activation_145[0][0]
# __________________________________________________________________________________________________
# concatenate_48 (Concatenate)    (None, 8, 8, 342)    0           concatenate_47[0][0]
#                                                                  conv2d_151[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_3 (AveragePoo (None, 1, 1, 342)    0           concatenate_48[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 342)          0           average_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 10)           3430        flatten_1[0][0]
# ==================================================================================================
# Total params: 797,788
# Trainable params: 774,376
# Non-trainable params: 23,412
# __________________________________________________________________________________________________
# Using real-time data augmentation.
# Learning rate:  0.001
# Epoch 1/100
# 1563/1563 [==============================] - ETA: 0s - loss: 1.5224 - acc: 0.4516
# Epoch 00001: val_acc improved from -inf to 0.55260, saving model to /content/saved_models/cifar10_densenet_model.01.h5
# 1563/1563 [==============================] - 366s 234ms/step - loss: 1.5224 - acc: 0.4516 - val_loss: 1.4882 - val_acc: 0.5526
# Learning rate:  0.001
# Epoch 2/100
# 1563/1563 [==============================] - ETA: 0s - loss: 1.0043 - acc: 0.6453
# Epoch 00002: val_acc improved from 0.55260 to 0.61480, saving model to /content/saved_models/cifar10_densenet_model.02.h5
# 1563/1563 [==============================] - 362s 232ms/step - loss: 1.0043 - acc: 0.6453 - val_loss: 1.2995 - val_acc: 0.6148
# Learning rate:  0.001
# Epoch 3/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.7709 - acc: 0.7302
# Epoch 00003: val_acc improved from 0.61480 to 0.67600, saving model to /content/saved_models/cifar10_densenet_model.03.h5
# 1563/1563 [==============================] - 362s 232ms/step - loss: 0.7709 - acc: 0.7302 - val_loss: 1.0577 - val_acc: 0.6760
# Learning rate:  0.001
# Epoch 4/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.6471 - acc: 0.7760
# Epoch 00004: val_acc did not improve from 0.67600
# 1563/1563 [==============================] - 363s 232ms/step - loss: 0.6471 - acc: 0.7760 - val_loss: 1.0960 - val_acc: 0.6707
# Learning rate:  0.001
# Epoch 5/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5674 - acc: 0.8045
# Epoch 00005: val_acc improved from 0.67600 to 0.77200, saving model to /content/saved_models/cifar10_densenet_model.05.h5
# 1563/1563 [==============================] - 364s 233ms/step - loss: 0.5674 - acc: 0.8045 - val_loss: 0.6970 - val_acc: 0.7720
# Learning rate:  0.001
# Epoch 6/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.5100 - acc: 0.8245
# Epoch 00006: val_acc did not improve from 0.77200
# 1563/1563 [==============================] - 364s 233ms/step - loss: 0.5100 - acc: 0.8245 - val_loss: 0.7957 - val_acc: 0.7443
# Learning rate:  0.001
# Epoch 7/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4690 - acc: 0.8388
# Epoch 00007: val_acc did not improve from 0.77200
# 1563/1563 [==============================] - 362s 232ms/step - loss: 0.4690 - acc: 0.8388 - val_loss: 0.7084 - val_acc: 0.7718
# Learning rate:  0.001
# Epoch 8/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4372 - acc: 0.8498
# Epoch 00008: val_acc improved from 0.77200 to 0.81610, saving model to /content/saved_models/cifar10_densenet_model.08.h5
# 1563/1563 [==============================] - 363s 233ms/step - loss: 0.4372 - acc: 0.8498 - val_loss: 0.5937 - val_acc: 0.8161
# Learning rate:  0.001
# Epoch 9/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.4056 - acc: 0.8600
# Epoch 00009: val_acc improved from 0.81610 to 0.81670, saving model to /content/saved_models/cifar10_densenet_model.09.h5
# 1563/1563 [==============================] - 363s 233ms/step - loss: 0.4056 - acc: 0.8600 - val_loss: 0.5800 - val_acc: 0.8167
# Learning rate:  0.001
# Epoch 10/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3778 - acc: 0.8699
# Epoch 00010: val_acc improved from 0.81670 to 0.83840, saving model to /content/saved_models/cifar10_densenet_model.10.h5
# 1563/1563 [==============================] - 364s 233ms/step - loss: 0.3778 - acc: 0.8699 - val_loss: 0.4924 - val_acc: 0.8384
# Learning rate:  0.001
# Epoch 11/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3645 - acc: 0.8748
# Epoch 00011: val_acc did not improve from 0.83840
# 1563/1563 [==============================] - 363s 232ms/step - loss: 0.3645 - acc: 0.8748 - val_loss: 0.6868 - val_acc: 0.7920
# Learning rate:  0.001
# Epoch 12/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3397 - acc: 0.8809
# Epoch 00012: val_acc did not improve from 0.83840
# 1563/1563 [==============================] - 362s 232ms/step - loss: 0.3397 - acc: 0.8809 - val_loss: 0.5113 - val_acc: 0.8342
# Learning rate:  0.001
# Epoch 13/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3247 - acc: 0.8882
# Epoch 00013: val_acc did not improve from 0.83840
# 1563/1563 [==============================] - 362s 232ms/step - loss: 0.3247 - acc: 0.8882 - val_loss: 0.9521 - val_acc: 0.7576
# Learning rate:  0.001
# Epoch 14/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.3083 - acc: 0.8934
# Epoch 00014: val_acc improved from 0.83840 to 0.84510, saving model to /content/saved_models/cifar10_densenet_model.14.h5
# 1563/1563 [==============================] - 364s 233ms/step - loss: 0.3083 - acc: 0.8934 - val_loss: 0.5021 - val_acc: 0.8451
# Learning rate:  0.001
# Epoch 15/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2920 - acc: 0.8998
# Epoch 00015: val_acc did not improve from 0.84510
# 1563/1563 [==============================] - 364s 233ms/step - loss: 0.2920 - acc: 0.8998 - val_loss: 0.5586 - val_acc: 0.8362
# Learning rate:  0.001
# Epoch 16/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2780 - acc: 0.9046
# Epoch 00016: val_acc improved from 0.84510 to 0.84930, saving model to /content/saved_models/cifar10_densenet_model.16.h5
# 1563/1563 [==============================] - 364s 233ms/step - loss: 0.2780 - acc: 0.9046 - val_loss: 0.5165 - val_acc: 0.8493
# Learning rate:  0.001
# Epoch 17/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2671 - acc: 0.9069
# Epoch 00017: val_acc did not improve from 0.84930
# 1563/1563 [==============================] - 362s 232ms/step - loss: 0.2671 - acc: 0.9069 - val_loss: 0.6293 - val_acc: 0.8126
# Learning rate:  0.001
# Epoch 18/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2577 - acc: 0.9106
# Epoch 00018: val_acc improved from 0.84930 to 0.85030, saving model to /content/saved_models/cifar10_densenet_model.18.h5
# 1563/1563 [==============================] - 364s 233ms/step - loss: 0.2577 - acc: 0.9106 - val_loss: 0.5006 - val_acc: 0.8503
# Learning rate:  0.001
# Epoch 19/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2476 - acc: 0.9147
# Epoch 00019: val_acc improved from 0.85030 to 0.87350, saving model to /content/saved_models/cifar10_densenet_model.19.h5
# 1563/1563 [==============================] - 366s 234ms/step - loss: 0.2476 - acc: 0.9147 - val_loss: 0.3817 - val_acc: 0.8735
# Learning rate:  0.001
# Epoch 20/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2400 - acc: 0.9162
# Epoch 00020: val_acc did not improve from 0.87350
# 1563/1563 [==============================] - 368s 235ms/step - loss: 0.2400 - acc: 0.9162 - val_loss: 0.4528 - val_acc: 0.8590
# Learning rate:  0.001
# Epoch 21/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2317 - acc: 0.9191
# Epoch 00021: val_acc did not improve from 0.87350
# 1563/1563 [==============================] - 363s 232ms/step - loss: 0.2317 - acc: 0.9191 - val_loss: 0.4434 - val_acc: 0.8725
# Learning rate:  0.001
# Epoch 22/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2241 - acc: 0.9227
# Epoch 00022: val_acc improved from 0.87350 to 0.87680, saving model to /content/saved_models/cifar10_densenet_model.22.h5
# 1563/1563 [==============================] - 363s 232ms/step - loss: 0.2241 - acc: 0.9227 - val_loss: 0.4118 - val_acc: 0.8768
# Learning rate:  0.001
# Epoch 23/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2142 - acc: 0.9267
# Epoch 00023: val_acc did not improve from 0.87680
# 1563/1563 [==============================] - 362s 232ms/step - loss: 0.2142 - acc: 0.9267 - val_loss: 0.4210 - val_acc: 0.8760
# Learning rate:  0.001
# Epoch 24/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2057 - acc: 0.9289
# Epoch 00024: val_acc did not improve from 0.87680
# 1563/1563 [==============================] - 362s 232ms/step - loss: 0.2057 - acc: 0.9289 - val_loss: 0.4520 - val_acc: 0.8719
# Learning rate:  0.001
# Epoch 25/100
# 1563/1563 [==============================] - ETA: 0s - loss: 0.2012 - acc: 0.9302
# Epoch 00025: val_acc did not improve from 0.87680
# 1563/1563 [==============================] - 362s 232ms/step - loss: 0.2012 - acc: 0.9302 - val_loss: 0.4384 - val_acc: 0.8738
# Learning rate:  0.001
# Epoch 26/100
#   10/1563 [..............................] - ETA: 5:09 - loss: 0.1565 - acc: 0.9312
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-a1ca098fd068> in <module>()
#     207               validation_data=(x_test, y_test),
#     208               steps_per_epoch=steps_per_epoch,
# --> 209               callbacks=callbacks)
#     210
#     211
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
